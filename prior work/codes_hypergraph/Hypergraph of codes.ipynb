# %%
import pandas as pd
import xgi
import numpy as np
import igraph as ig
import networkx
import itertools
# Out:
# <frozen importlib._bootstrap>:219: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
#Read in CSV file with coding
df = pd.read_csv("Final Coding.csv",keep_default_na=False)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1129 entries, 0 to 1128
# Data columns (total 44 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unnamed: 0                    1129 non-null   int64
#  1   tweet_id                      1129 non-null   int64
#  2   user_username                 1129 non-null   object
#  3   text                          1129 non-null   object
#  4   created_at                    1129 non-null   object
#  5   conversation_id               1129 non-null   int64
#  6   lang                          1129 non-null   object
#  7   possibly_sensitive            1129 non-null   bool
#  8   author_id                     1129 non-null   int64
#  9   source                        1129 non-null   object
#  10  in_reply_to_user_id           1129 non-null   object
#  11  user_verified                 1129 non-null   bool
#  12  user_profile_image_url        1129 non-null   object
#  13  user_name                     1129 non-null   object
#  14  user_protected                1129 non-null   bool
#  15  user_created_at               1129 non-null   object
#  16  user_location                 1129 non-null   object
#  17  user_description              1129 non-null   object
#  18  user_url                      1129 non-null   object
#  19  user_pinned_tweet_id          1129 non-null   object
#  20  retweet_count                 1129 non-null   int64
#  21  like_count                    1129 non-null   int64
#  22  quote_count                   1129 non-null   int64
#  23  user_tweet_count              1129 non-null   int64
#  24  user_list_count               1129 non-null   int64
#  25  user_followers_count          1129 non-null   int64
#  26  user_following_count          1129 non-null   int64
#  27  sourcetweet_type              1129 non-null   object
#  28  sourcetweet_id                1129 non-null   object
#  29  sourcetweet_text              1129 non-null   object
#  30  Code                          1129 non-null   object
#  31  sourcetweet_lang              1129 non-null   object
#  32  sourcetweet_author_id         1129 non-null   object
#  33  Self-organization             1129 non-null   int64
#  34  SO code                       1129 non-null   object
#  35  Building community            1129 non-null   int64
#  36  BC code                       1129 non-null   object
#  37  Broadening the counterpublic  1129 non-null   int64
#  38  BtC code                      1129 non-null   object
#  39  Creating change in math       1129 non-null   int64
#  40  CCM code                      1129 non-null   object
#  41  SJEDI                         1129 non-null   int64
#  42  SJEDI code                    1129 non-null   object
#  43  CODER                         1129 non-null   object
# dtypes: bool(3), int64(16), object(25)
# memory usage: 365.1+ KB

# %%
#The codes were in 5 different columns; lets aggregate them into a new column
df["all codes"] = df[["SO code","BC code","BtC code","CCM code","SJEDI code"]].agg(';'.join,axis=1)
#We separated them by ;, so convert to an array 
df["all codes"] = df["all codes"].apply(lambda s: s.split(';'))
#Strip out leading/trailing spaces
df["all codes"] = df["all codes"].apply(lambda s: [t.strip() for t in s if t])
#Sort the arrays, so we can be confident the same things are not listed in two different ways
df["all codes"] = df["all codes"].apply(sorted)
#Convert back to string with ; between the codes
df["all codes"] = df["all codes"].apply(lambda s: ';'.join(s))

#We need to make a list of tuples with the first n-1 entries being the codes, and the last one being the weight
#First, make a dictionary with the codes and their weights
weighted_codes = df["all codes"].value_counts().to_dict()

#Now iterate through the dictionary and create a list of tuples
weighted_edge_list_formatted=[]
for el in list(weighted_codes.items()):
    weighted_edge_list_formatted.append(tuple(el[0].split(';'))+(el[1],))     #el[1] is an integer, (el[1],) makes it into a 1-tuple

#Display the first 10 weighted edges
print(weighted_edge_list_formatted[0:10])
# Out:
# [('advocacy', 'amplification', 'emotional support', 'gender', 'indigenous', 'jmm experience', 'representation', 86), ('amplification', 'bipoc', 'hashtags', 'influencers', 'power', 'talk support', 47), ('humanize', 'math practice', 36), ('amplification', 'influencers', 'representation', 'talk support', 30), ('bipoc', 'current events', 'power', 'talk support', 22), ('amplification', 21), ('amplification', 'lgbtq', 'talk support', 19), ('amplification', 'hashtags', 'influencers', 'math practice', 'talk support', 19), ('amplification', 'humanize', 'influencers', 'talk support', 19), ('hashtags', 'representation', 'strategic planning', 19)]

# %%
H = xgi.Hypergraph()
H.add_weighted_edges_from(weighted_edge_list_formatted)

# %%
print(H)
# Out:
# Unnamed Hypergraph with 35 nodes and 216 hyperedges

# %%
xgi.draw(H,node_labels=True)
# Out:
# <Axes: >

# %%
dict(sorted(xgi.clique_eigenvector_centrality(H).items(), key=lambda item: -1*item[1]))
# Out:
# {'amplification': 0.12780472140446725,
#  'talk support': 0.11891958807603756,
#  'hashtags': 0.11089739075846876,
#  'influencers': 0.09776852372642483,
#  'power': 0.05743041122442991,
#  'representation': 0.05209918578418304,
#  'humanize': 0.04317917119904656,
#  'bipoc': 0.04162943009019714,
#  'math practice': 0.040053850412701666,
#  'indigenous': 0.0388027470307918,
#  'gender': 0.0337584099590626,
#  'advocacy': 0.03255185258402352,
#  'BC impact': 0.028036225390716166,
#  'strategic planning': 0.019217754257627825,
#  'thankful': 0.018086498899867683,
#  'lgbtq': 0.017394594207099087,
#  'current events': 0.01665613124939036,
#  'conversation': 0.015465542227332887,
#  'allyship in math': 0.014182471559075536,
#  'learning': 0.014090465456723043,
#  'emotional support': 0.010028752800436596,
#  'jmm experience': 0.009830956576335538,
#  'belonging': 0.009756303471298466,
#  'SO impact': 0.008548798111638316,
#  'math experience': 0.004448163056753384,
#  'economic': 0.0042795403751474444,
#  'disrupteverything': 0.0033933086584511515,
#  'futures': 0.002783652081805782,
#  'CC impact': 0.001863695006643088,
#  'virtual participation': 0.0017292434686507479,
#  'activation': 0.0017235965291361982,
#  'celebration': 0.0016617468530871454,
#  'troll': 0.0014632653006327661,
#  'SJEDI impact': 0.00036434381298486036,
#  'beyond': 9.966839933122913e-05}

# %%
kc=xgi.katz_centrality(H,index=True)
d={ item[1]:kc[0][item[0]] for item in kc[1].items()}
dict(sorted(d.items(),key=lambda item: -1*item[1]))
# Out:
# {'amplification': 8.314285750218966,
#  'talk support': 7.571428605260526,
#  'hashtags': 7.257142888471052,
#  'influencers': 5.800000028196622,
#  'power': 3.3428571593066274,
#  'representation': 3.171428586390436,
#  'bipoc': 2.4571428690388406,
#  'indigenous': 2.3714285826002848,
#  'humanize': 2.257142869437977,
#  'math practice': 2.1714285828206417,
#  'gender': 2.171428581093537,
#  'advocacy': 2.057142866388728,
#  'BC impact': 2.0285714365882863,
#  'conversation': 1.485714290260304,
#  'strategic planning': 1.4000000057018558,
#  'thankful': 1.3428571481124634,
#  'current events': 1.1714285762090835,
#  'lgbtq': 0.9142857192009355,
#  'emotional support': 0.8571428600939854,
#  'SO impact': 0.8285714311084511,
#  'allyship in math': 0.7714285755230645,
#  'learning': 0.7714285754540467,
#  'belonging': 0.6857142885548194,
#  'jmm experience': 0.6857142885539877,
#  'futures': 0.34285714370198545,
#  'math experience': 0.314285715571272,
#  'activation': 0.20000000050224895,
#  'economic': 0.17142857265093234,
#  'disrupteverything': 0.17142857242309095,
#  'CC impact': 0.17142857200066958,
#  'virtual participation': 0.1428571433677072,
#  'troll': 0.14285714328538496,
#  'SJEDI impact': 0.11428571441293962,
#  'celebration': 0.08571428620489317,
#  'beyond': 0.02857142861466856}

# %% [markdown]
# ## Clusters

# %%
G=xgi.convert_to_graph(H)
networkx.community.greedy_modularity_communities(G)
# Out:
# [frozenset({'activation',
#             'advocacy',
#             'bipoc',
#             'current events',
#             'emotional support',
#             'gender',
#             'humanize',
#             'indigenous',
#             'influencers',
#             'jmm experience',
#             'learning',
#             'lgbtq',
#             'math practice',
#             'power',
#             'troll'}),
#  frozenset({'BC impact',
#             'CC impact',
#             'SJEDI impact',
#             'SO impact',
#             'belonging',
#             'beyond',
#             'celebration',
#             'conversation',
#             'futures',
#             'strategic planning',
#             'talk support',
#             'thankful',
#             'virtual participation'}),
#  frozenset({'allyship in math',
#             'amplification',
#             'disrupteverything',
#             'economic',
#             'hashtags',
#             'math experience',
#             'representation'})]

# %% [markdown]
# ## Export a weighted edge list so Carrie can play around in R with it

# %%
f=open("codes edge list.csv","w") 
#Iterate over our code dictionary we created above
for (codes,weight) in weighted_codes.items():
    #Codes is a string containing the codes separated by ;, so split this into an array of individual codes
    split_codes = codes.split(";")
    #We want to turn each hyperedge into an edge for each pair
    #So this iterates over pairs of codes
    for (c,d) in list(itertools.permutations(split_codes,2)):
        #Put a line in the edgelist for each weight
        for i in range (0,weight):
            f.write(c+","+d+"\n")

# %% [markdown]
# ## In periods of time

# %%
#filtering the dataset by year
df2019 = df[df['created_at'].str.contains("2019-")].copy()
df2020 = df[df['created_at'].str.contains("2020-")].copy()
df2021 = df[df['created_at'].str.contains("2021-")].copy()

# %%
#using Drew's code to create a function for our hypergraphs

def create_twitter_hypergraph(df):
    """Given a dataframe with our disruptJMM coding information attached as in Final Coding.csv, create the hypergraph of codes"""
    #The codes were in 5 different columns; lets aggregate them into a new column
    df["all codes"] = df[["SO code","BC code","BtC code","CCM code","SJEDI code"]].agg(';'.join,axis=1)
    #We separated them by ;, so convert to an array 
    df["all codes"] = df["all codes"].apply(lambda s: s.split(';'))
    #Strip out leading/trailing spaces
    df["all codes"] = df["all codes"].apply(lambda s: [t.strip() for t in s if t])
    #Sort the arrays, so we can be confident the same things are not listed in two different ways
    df["all codes"] = df["all codes"].apply(sorted)
    #Convert back to string with ; between the codes
    df["all codes"] = df["all codes"].apply(lambda s: ';'.join(s))

    #We need to make a list of tuples with the first n-1 entries being the codes, and the last one being the weight
    #First, make a dictionary with the codes and their weights
    weighted_codes = df["all codes"].value_counts().to_dict()

    #Now iterate through the dictionary and create a list of tuples
    weighted_edge_list_formatted=[]
    for el in list(weighted_codes.items()):
        weighted_edge_list_formatted.append(tuple(el[0].split(';'))+(el[1],))    #el[1] is an integer, (el[1],) makes it into a 1-tuple
    H = xgi.Hypergraph()
    H.add_weighted_edges_from(weighted_edge_list_formatted)
    return H

# %%
H2019 = create_twitter_hypergraph(df2019)
H2020 = create_twitter_hypergraph(df2020)
H2021 = create_twitter_hypergraph(df2021)

# %%
xgi.draw(H2019,node_labels=True)
H2019.nodes.degree.asdict()
# Out:
# {'amplification': 2,
#  'hashtags': 2,
#  'humanize': 1,
#  'influencers': 1,
#  'representation': 1,
#  'strategic planning': 1,
#  'BC impact': 1,
#  'conversation': 2}

# %%
xgi.draw(H2020,node_labels=True)
# Out:
# <Axes: >

# %%
xgi.draw(H2021,node_labels=True)
# Out:
# <Axes: >

# %%
code_df= pd.read_csv("Code Book.csv")
code_df
# Out:
#     self organization building community broadening the counterpublic  \
# 0       amplification           thankful            disrupteverything
# 1          activation       talk support                  influencers
# 2  strategic planning          belonging                       beyond
# 3           SO impact  emotional support                     hashtags
# 4               troll  expertise support        virtual participation
# 5                 NaN       conversation                          NaN
# 6                 NaN        celebration                          NaN
# 7                 NaN          BC impact                          NaN
# 8                 NaN                NaN                          NaN
# 9                 NaN                NaN                          NaN
#
#   creating change in math           SJEDI
# 0                humanize  representation
# 1          jmm experience           lgbtq
# 2         math experience           bipoc
# 3                 futures          gender
# 4           math practice      indigenous
# 5          current events           power
# 6        allyship in math        advocacy
# 7               CC impact        learning
# 8                     NaN        economic
# 9                     NaN    SJEDI impact

# %%
#dictionary color coding the themes
code_dict = {'self organization': 'red', 'building community':'yellow', 'broadening the counterpublic':'green', 'creating change in math': 'blue', 'SJEDI':'purple' }

# %%
H.nodes
# Out:
# NodeView(('advocacy', 'amplification', 'emotional support', 'gender', 'indigenous', 'jmm experience', 'representation', 'bipoc', 'hashtags', 'influencers', 'power', 'talk support', 'humanize', 'math practice', 'current events', 'lgbtq', 'strategic planning', 'allyship in math', 'math experience', 'conversation', 'thankful', 'BC impact', 'disrupteverything', 'SJEDI impact', 'SO impact', 'belonging', 'learning', 'troll', 'CC impact', 'virtual participation', 'activation', 'futures', 'economic', 'beyond', 'celebration'))

# %%
#for each node in the hypergraph, find what theme it exists in and give it a color
color_dict = {n: code_dict[np.array(code_df.columns[code_df.isin([n]).any()])[0]] for n in H.nodes}
color_dict
# Out:
# {'advocacy': 'purple',
#  'amplification': 'red',
#  'emotional support': 'yellow',
#  'gender': 'purple',
#  'indigenous': 'purple',
#  'jmm experience': 'blue',
#  'representation': 'purple',
#  'bipoc': 'purple',
#  'hashtags': 'green',
#  'influencers': 'green',
#  'power': 'purple',
#  'talk support': 'yellow',
#  'humanize': 'blue',
#  'math practice': 'blue',
#  'current events': 'blue',
#  'lgbtq': 'purple',
#  'strategic planning': 'red',
#  'allyship in math': 'blue',
#  'math experience': 'blue',
#  'conversation': 'yellow',
#  'thankful': 'yellow',
#  'BC impact': 'yellow',
#  'disrupteverything': 'green',
#  'SJEDI impact': 'purple',
#  'SO impact': 'red',
#  'belonging': 'yellow',
#  'learning': 'purple',
#  'troll': 'red',
#  'CC impact': 'blue',
#  'virtual participation': 'green',
#  'activation': 'red',
#  'futures': 'blue',
#  'economic': 'purple',
#  'beyond': 'green',
#  'celebration': 'yellow'}

# %%
xgi.draw(H2019,node_labels=True,node_fc= color_dict)
H2019.nodes.degree.asdict()
# Out:
# {'amplification': 2,
#  'hashtags': 2,
#  'humanize': 1,
#  'influencers': 1,
#  'representation': 1,
#  'strategic planning': 1,
#  'BC impact': 1,
#  'conversation': 2}

# %%
xgi.draw(H2020,node_labels=False, node_fc= color_dict,)
H2020.nodes.degree.asdict()
# Out:
# {'advocacy': 17,
#  'amplification': 78,
#  'emotional support': 11,
#  'gender': 15,
#  'indigenous': 14,
#  'jmm experience': 7,
#  'representation': 30,
#  'humanize': 21,
#  'math practice': 21,
#  'influencers': 53,
#  'talk support': 63,
#  'hashtags': 70,
#  'strategic planning': 20,
#  'lgbtq': 9,
#  'conversation': 20,
#  'allyship in math': 6,
#  'math experience': 3,
#  'thankful': 19,
#  'BC impact': 28,
#  'power': 25,
#  'current events': 3,
#  'disrupteverything': 3,
#  'bipoc': 14,
#  'SJEDI impact': 2,
#  'learning': 9,
#  'SO impact': 12,
#  'belonging': 12,
#  'activation': 4,
#  'CC impact': 3,
#  'virtual participation': 4,
#  'futures': 5,
#  'troll': 1,
#  'economic': 2,
#  'beyond': 1,
#  'celebration': 1}

# %%
xgi.draw(H2021,node_labels=False,node_fc= color_dict, node_size= H2021.nodes.degree.asdict())
# Out:
# <Axes: >

# %%
temp = H.nodes.degree.asdict()
H_node_size = {n: temp[n]/4 for n in temp.keys()}
H_node_size
# Out:
# {'advocacy': 5.0,
#  'amplification': 22.5,
#  'emotional support': 3.5,
#  'gender': 5.25,
#  'indigenous': 5.25,
#  'jmm experience': 1.75,
#  'representation': 8.5,
#  'bipoc': 6.25,
#  'hashtags': 20.0,
#  'influencers': 15.25,
#  'power': 9.0,
#  'talk support': 21.0,
#  'humanize': 5.75,
#  'math practice': 6.25,
#  'current events': 3.25,
#  'lgbtq': 2.25,
#  'strategic planning': 5.0,
#  'allyship in math': 2.0,
#  'math experience': 0.75,
#  'conversation': 6.25,
#  'thankful': 5.5,
#  'BC impact': 8.25,
#  'disrupteverything': 0.75,
#  'SJEDI impact': 0.5,
#  'SO impact': 3.25,
#  'belonging': 3.0,
#  'learning': 2.5,
#  'troll': 0.5,
#  'CC impact': 1.0,
#  'virtual participation': 1.0,
#  'activation': 1.0,
#  'futures': 1.25,
#  'economic': 0.5,
#  'beyond': 0.25,
#  'celebration': 0.5}

# %%
xgi.draw(H, node_fc= color_dict, node_size = H_node_size)
# Out:
# <Axes: >

# %%
H.edges.attrs.asdict()
# Out:
# {0: {'weight': 86},
#  1: {'weight': 47},
#  2: {'weight': 36},
#  3: {'weight': 30},
#  4: {'weight': 22},
#  5: {'weight': 21},
#  6: {'weight': 19},
#  7: {'weight': 19},
#  8: {'weight': 19},
#  9: {'weight': 19},
#  10: {'weight': 15},
#  11: {'weight': 14},
#  12: {'weight': 14},
#  13: {'weight': 14},
#  14: {'weight': 13},
#  15: {'weight': 12},
#  16: {'weight': 11},
#  17: {'weight': 11},
#  18: {'weight': 11},
#  19: {'weight': 11},
#  20: {'weight': 11},
#  21: {'weight': 11},
#  22: {'weight': 10},
#  23: {'weight': 10},
#  24: {'weight': 10},
#  25: {'weight': 10},
#  26: {'weight': 10},
#  27: {'weight': 10},
#  28: {'weight': 9},
#  29: {'weight': 9},
#  30: {'weight': 9},
#  31: {'weight': 9},
#  32: {'weight': 9},
#  33: {'weight': 9},
#  34: {'weight': 9},
#  35: {'weight': 8},
#  36: {'weight': 8},
#  37: {'weight': 8},
#  38: {'weight': 7},
#  39: {'weight': 7},
#  40: {'weight': 7},
#  41: {'weight': 7},
#  42: {'weight': 7},
#  43: {'weight': 7},
#  44: {'weight': 6},
#  45: {'weight': 6},
#  46: {'weight': 6},
#  47: {'weight': 6},
#  48: {'weight': 6},
#  49: {'weight': 6},
#  50: {'weight': 6},
#  51: {'weight': 6},
#  52: {'weight': 6},
#  53: {'weight': 6},
#  54: {'weight': 6},
#  55: {'weight': 5},
#  56: {'weight': 5},
#  57: {'weight': 5},
#  58: {'weight': 5},
#  59: {'weight': 5},
#  60: {'weight': 5},
#  61: {'weight': 5},
#  62: {'weight': 5},
#  63: {'weight': 5},
#  64: {'weight': 5},
#  65: {'weight': 5},
#  66: {'weight': 5},
#  67: {'weight': 5},
#  68: {'weight': 5},
#  69: {'weight': 5},
#  70: {'weight': 5},
#  71: {'weight': 5},
#  72: {'weight': 4},
#  73: {'weight': 4},
#  74: {'weight': 4},
#  75: {'weight': 4},
#  76: {'weight': 4},
#  77: {'weight': 4},
#  78: {'weight': 4},
#  79: {'weight': 4},
#  80: {'weight': 4},
#  81: {'weight': 4},
#  82: {'weight': 4},
#  83: {'weight': 4},
#  84: {'weight': 4},
#  85: {'weight': 4},
#  86: {'weight': 4},
#  87: {'weight': 4},
#  88: {'weight': 4},
#  89: {'weight': 4},
#  90: {'weight': 4},
#  91: {'weight': 4},
#  92: {'weight': 4},
#  93: {'weight': 4},
#  94: {'weight': 4},
#  95: {'weight': 4},
#  96: {'weight': 4},
#  97: {'weight': 3},
#  98: {'weight': 3},
#  99: {'weight': 3},
#  100: {'weight': 3},
#  101: {'weight': 3},
#  102: {'weight': 3},
#  103: {'weight': 3},
#  104: {'weight': 3},
#  105: {'weight': 3},
#  106: {'weight': 3},
#  107: {'weight': 3},
#  108: {'weight': 3},
#  109: {'weight': 3},
#  110: {'weight': 3},
#  111: {'weight': 3},
#  112: {'weight': 3},
#  113: {'weight': 3},
#  114: {'weight': 3},
#  115: {'weight': 3},
#  116: {'weight': 3},
#  117: {'weight': 3},
#  118: {'weight': 3},
#  119: {'weight': 3},
#  120: {'weight': 3},
#  121: {'weight': 3},
#  122: {'weight': 3},
#  123: {'weight': 3},
#  124: {'weight': 2},
#  125: {'weight': 2},
#  126: {'weight': 2},
#  127: {'weight': 2},
#  128: {'weight': 2},
#  129: {'weight': 2},
#  130: {'weight': 2},
#  131: {'weight': 2},
#  132: {'weight': 2},
#  133: {'weight': 2},
#  134: {'weight': 2},
#  135: {'weight': 2},
#  136: {'weight': 2},
#  137: {'weight': 2},
#  138: {'weight': 2},
#  139: {'weight': 2},
#  140: {'weight': 2},
#  141: {'weight': 2},
#  142: {'weight': 2},
#  143: {'weight': 2},
#  144: {'weight': 2},
#  145: {'weight': 2},
#  146: {'weight': 2},
#  147: {'weight': 2},
#  148: {'weight': 2},
#  149: {'weight': 2},
#  150: {'weight': 2},
#  151: {'weight': 2},
#  152: {'weight': 2},
#  153: {'weight': 2},
#  154: {'weight': 2},
#  155: {'weight': 2},
#  156: {'weight': 2},
#  157: {'weight': 2},
#  158: {'weight': 2},
#  159: {'weight': 2},
#  160: {'weight': 2},
#  161: {'weight': 2},
#  162: {'weight': 2},
#  163: {'weight': 2},
#  164: {'weight': 2},
#  165: {'weight': 2},
#  166: {'weight': 2},
#  167: {'weight': 2},
#  168: {'weight': 2},
#  169: {'weight': 2},
#  170: {'weight': 2},
#  171: {'weight': 2},
#  172: {'weight': 2},
#  173: {'weight': 2},
#  174: {'weight': 1},
#  175: {'weight': 1},
#  176: {'weight': 1},
#  177: {'weight': 1},
#  178: {'weight': 1},
#  179: {'weight': 1},
#  180: {'weight': 1},
#  181: {'weight': 1},
#  182: {'weight': 1},
#  183: {'weight': 1},
#  184: {'weight': 1},
#  185: {'weight': 1},
#  186: {'weight': 1},
#  187: {'weight': 1},
#  188: {'weight': 1},
#  189: {'weight': 1},
#  190: {'weight': 1},
#  191: {'weight': 1},
#  192: {'weight': 1},
#  193: {'weight': 1},
#  194: {'weight': 1},
#  195: {'weight': 1},
#  196: {'weight': 1},
#  197: {'weight': 1},
#  198: {'weight': 1},
#  199: {'weight': 1},
#  200: {'weight': 1},
#  201: {'weight': 1},
#  202: {'weight': 1},
#  203: {'weight': 1},
#  204: {'weight': 1},
#  205: {'weight': 1},
#  206: {'weight': 1},
#  207: {'weight': 1},
#  208: {'weight': 1},
#  209: {'weight': 1},
#  210: {'weight': 1},
#  211: {'weight': 1},
#  212: {'weight': 1},
#  213: {'weight': 1},
#  214: {'weight': 1},
#  215: {'weight': 1}}
